# %%
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
import pandas as pd
from bs4 import BeautifulSoup

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/data/khuangaf/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
df= pd.read_csv('data/ASSISTmentsProblems.csv')
df.body = df.body.astype('string')
df['parsed'] = df.apply(lambda(row): BeautifulSoup(row['body'], 'html.parser').get_text() , axis=1)
df
# Out:
#         problem_id                                               body  \
# 0              134  But remember, we need to find the area of the ...
# 1              135  By the way, did you notice that side AC belong...
# 2              171  What is the length of one side of a square in ...
# 3              183  <p>It is not always possible to make a triangl...
# 4              184  <p>Now match up the lengths to see if they wil...
# 5              185  <p>Which set of line segments cannot be used t...
# 6              359  Good, now that we know how to convert from squ...
# 7              395  The measurement of the room is in square feet,...
# 8              396  <p>The area of the square in the picture is 1 ...
# 9              397  <p>What is the area of the library in square f...
# 10             398  <p><span style="color: #0000ff;">Now we need t...
# 11             434  Good, 0.21 is 21% in decimal form. Now we want...
# 12             435  <p>Good, 0.21 times 15,970 will give you the n...
# 13             441  Write an <b>expression</b> that tells how much...
# 14             445  <p>We need two things: the number of right ang...
# 15             452  How many units apart are -6 and 4 on the numbe...
# 16             465  <p>\n<table id="j20o1" border="0" cellspacing=...
# 17             557  Which graph above matches the inequality <b>x ...
# 18             579  In order to find out which number comes next i...
# 19             580  Good, the difference between the first two ele...
# 20             581  Good, the difference between 9 and 6 is <b>3</...
# 21             582  Good, the difference between 14 and 9 is <b>5<...
# 22             811  Why don't we break it down.  What is 1.20 minu...
# 23             812  Now, 34 minus 5 is?<br/><img class="assistment...
# 24             840  Order of operations tells us to start inside t...
# 25             841  Good, now we have <b>8 - (16)</b>. What is thi...
# 26             842                           Compute 8 - (-5 + 3 * 7)
# 27             843  Is (-4)<sup>3</sup> a positive or a negative n...
# 28             863  First, let's figure out which <B>fraction of t...
# 29             864  What is 1/4 of 697 rounded to the nearest inte...
# ...            ...                                                ...
# 128942      767001  <p><img class="Wirisformula" src="/pluginwiris...
# 128943      767002  <p><img class="Wirisformula" src="/pluginwiris...
# 128944      767005  <p>&nbsp;</p>\n<p>In the diagram below,&nbsp;<...
# 128945      767006  <p>In the diagram below, the arrowheads on the...
# 128946      767007  <p><img class="Wirisformula" src="/pluginwiris...
# 128947      767008  <p><img class="Wirisformula" src="/pluginwiris...
# 128948      767009  <p><img class="Wirisformula" src="/pluginwiris...
# 128949      767010  <p><img class="Wirisformula" src="/pluginwiris...
# 128950      767011  <p>What angle relationship did angles 2 and 3 ...
# 128951      767012                       <p>Find the value for x.</p>
# 128952      767013  <p>Two angles measures are labeled with y in t...
# 128953      767014                        <p>Find the value of y.</p>
# 128954      767015  <p>Write an agebraic expression for the produc...
# 128955      767016  <p>Write an agebraic expression for the 10 mor...
# 128956      767017  <p>Write an agebraic expression for the&nbsp;5...
# 128957      767018  <p>Write an agebraic expression for the&nbsp;1...
# 128958      767019  <p>Write an agebraic expression for the&nbsp;3...
# 128959      767060                                           <p>1</p>
# 128960      767076  <p>I walked 2.7 kilometers this week at school...
# 128961      767077  <p>The desk is 55 cm tall. &nbsp;How many mm i...
# 128962      767079                         <p>reference number 34</p>
# 128963      767080                         <p>reference number 35</p>
# 128964      767081                         <p>reference number 36</p>
# 128965      767082                         <p>reference number 37</p>
# 128966      767083                   <p>What is anet in geometry?</p>
# 128967      767139  <p>Doc Worker is a regular customer at the Wat...
# 128968      767140  <p>Doc Worker is a regular customer at the Wat...
# 128969      767141  <p>Doc Worker is a regular customer at the Wat...
# 128970      767142  <p>Doc Worker is a regular customer at the Wat...
# 128971      767143  <p>Doc Worker is a regular customer at the Wat...
#
#                                                    parsed
# 0       But remember, we need to find the area of the ...
# 1       By the way, did you notice that side AC belong...
# 2       What is the length of one side of a square in ...
# 3       It is not always possible to make a triangle u...
# 4       Now match up the lengths to see if they will f...
# 5       Which set of line segments cannot be used to f...
# 6       Good, now that we know how to convert from squ...
# 7       The measurement of the room is in square feet,...
# 8       The area of the square in the picture is 1 squ...
# 9       What is the area of the library in square feet...
# 10      Now we need to convert the area from square fe...
# 11      Good, 0.21 is 21% in decimal form. Now we want...
# 12      Good, 0.21 times 15,970 will give you the numb...
# 13      Write an expression that tells how much money ...
# 14      We need two things: the number of right angles...
# 15      How many units apart are -6 and 4 on the numbe...
# 16      \n\n\n\n\nNow we know  \n\n3  \n\n1\n  = \n 30...
# 17      Which graph above matches the inequality x <= ...
# 18      In order to find out which number comes next i...
# 19      Good, the difference between the first two ele...
# 20      Good, the difference between 9 and 6 is 3. Let...
# 21      Good, the difference between 14 and 9 is 5. Le...
# 22      Why don't we break it down.  What is 1.20 minu...
# 23                                    Now, 34 minus 5 is?
# 24      Order of operations tells us to start inside t...
# 25      Good, now we have 8 - (16). What is this equal...
# 26                               Compute 8 - (-5 + 3 * 7)
# 27              Is (-4)3 a positive or a negative number?
# 28      First, let's figure out which fraction of the ...
# 29      What is 1/4 of 697 rounded to the nearest inte...
# ...                                                   ...
# 128942
# 128943
# 128944   \nIn the diagram below, .\nFill in the angle ...
# 128945  In the diagram below, the arrowheads on the ve...
# 128946
# 128947
# 128948
# 128949
# 128950  What angle relationship did angles 2 and 3 hav...
# 128951                              Find the value for x.
# 128952  Two angles measures are labeled with y in thei...
# 128953                               Find the value of y.
# 128954  Write an agebraic expression for the product o...
# 128955  Write an agebraic expression for the 10 more t...
# 128956  Write an agebraic expression for the 5 less th...
# 128957  Write an agebraic expression for the 10 less t...
# 128958  Write an agebraic expression for the 30 more t...
# 128959                                                  1
# 128960  I walked 2.7 kilometers this week at school.  ...
# 128961  The desk is 55 cm tall.  How many mm is the desk?
# 128962                                reference number 34
# 128963                                reference number 35
# 128964                                reference number 36
# 128965                                reference number 37
# 128966                          What is anet in geometry?
# 128967  Doc Worker is a regular customer at the Waterf...
# 128968  Doc Worker is a regular customer at the Waterf...
# 128969  Doc Worker is a regular customer at the Waterf...
# 128970  Doc Worker is a regular customer at the Waterf...
# 128971  Doc Worker is a regular customer at the Waterf...
#
# [128972 rows x 3 columns]

# %%
#collect all the words into one list
filtered_words=[]
def count_words(row):
    global filtered_words
    filtered_words += [word for word in row['parsed'].split() if word not in stopwords.words('english')]
df.apply(count_words, axis=1)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None
# 10        None
# 11        None
# 12        None
# 13        None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 21        None
# 22        None
# 23        None
# 24        None
# 25        None
# 26        None
# 27        None
# 28        None
# 29        None
#           ...
# 128942    None
# 128943    None
# 128944    None
# 128945    None
# 128946    None
# 128947    None
# 128948    None
# 128949    None
# 128950    None
# 128951    None
# 128952    None
# 128953    None
# 128954    None
# 128955    None
# 128956    None
# 128957    None
# 128958    None
# 128959    None
# 128960    None
# 128961    None
# 128962    None
# 128963    None
# 128964    None
# 128965    None
# 128966    None
# 128967    None
# 128968    None
# 128969    None
# 128970    None
# 128971    None
# Length: 128972, dtype: object

# %%
vocabulary_size = 10000

def build_dataset(words):
    # UNK token is used to denote words that are not in the dictionary
    count = [['UNK', -1]]
    # returns set of tuples (word,count) with most common 50000 words
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    # set word count for all the words to the current number of keys in the dictionary
    # in other words values act as indices for each word
    # first word is 'UNK' representing unknown words we encounter
    for word, _ in count:
        dictionary[word] = len(dictionary)
    # this contains the words replaced by assigned indices
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(filtered_words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
# Out:
# Most common words (+UNK) [['UNK', 84465], (u'Page', 28673), (u'What', 15021), (u'answer', 11573), (u'Do', 10752)]
# Sample data [2389, 8046, 102, 55, 133, 3230, 391, 6800, 167, 101]

# %%
data_index = 0
def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
    assert skip_window%2==1

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]

    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side

    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)

    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself

        # do this num_skips (2 times)
        # do this (1 time)

        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])
# Out:
# data: [u'But', u'remember,', u'need', u'find', u'area', u'square.', u'So,', u"square's"]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
# pick 16 samples from 100
valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    # embedding, vector for each word in the vocabulary
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                     stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    # this might efficiently find the embeddings for given ids (traind dataset)
    # manually doing this might not be efficient given there are 50000 entries in embeddings
    embeds = None
    for i in range(2*skip_window):
        embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
        print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
        emb_x,emb_y = embedding_i.get_shape().as_list()
        if embeds is None:
            embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
        else:
            print(embedding_i)
            print(emb_x)
            print(emb_y)
            embeds = tf.concat([embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])],2)

    assert embeds.get_shape().as_list()[2]==2*skip_window
    print("Concat embedding size: %s"%embeds.get_shape().as_list())
    avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
    print("Avg embedding size: %s"%avg_embed.get_shape().as_list())

    '''embedding_0 = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
    embedding_1 = tf.nn.embedding_lookup(embeddings, train_dataset[:,1])
    avg_embed =  (embedding_0+embedding_1)/2.0
    print("Avg embedding size: %s"%avg_embed.get_shape().as_list())'''

    # Compute the softmax loss, using a sample of the negative labels each time.
    # inputs are embeddings of the train words
    # with this loss we optimize weights, biases, embeddings

    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, avg_embed, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    # Adagrad is required because there are too many things to optimize
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Tensor("embedding_lookup_1:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)
# 128
# 128
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.043101
# Nearest to 7: 85°, 96,, 370, _______, estimation, P7, must, 12x6,
# Nearest to For: rules, coordinate?, room,, Paul's, false(You, Thus, 42x, scaled,
# Nearest to What: #8c, models, figures., positive.(You, does., big, $13, Meg's,
# Nearest to #6: 2/x=12/6., 2d, 4a, demand, cost, Appalachian, 0.8,, characteristic,
# Nearest to Sorry,: New, hypothesis?, values?, spending, baseboards, Good!, √72, model,
# Nearest to write: Leaf, ___cm2, meeting?, (8x, Example, cubic, substance, histogram.,
# Nearest to 'Break: 638, P32, #37(You, #66, crops, Subtract, 368, -7.,
# Nearest to #2: 90-92, (SSS,, shore, (-4,, paint, appears., feature, 1/2,
# Nearest to Ms.: false(You, 0.82,, chart, said., ∏), -9, entering, (No,
# Nearest to value?: a*10^b.), rest, outcomes, Price, Ben, Japan, Released, (Don't,
# Nearest to area.: Negative, values., 46, basic, confidence, plate, 376, comparing,
# Nearest to e: 566, $2.00, stars, judged, -use, P25, prime, Jane,
# Nearest to -7: B)H0:, within, People,, correlation, 129, group, 144,, error.,
# Nearest to exact: E?, Post, carried, text, 69,, wood, siblings, process?,
# Nearest to 204: 2pi., _____., distinct, (leave, jeans, sister., -8x3, “It’s,
# Nearest to h,: $)(You, (Hint:, central, multiplicative, 2b., x), -8x3, #9(You,
# Average loss at step 2000: 1.770531
# Average loss at step 4000: 2.224432
# Average loss at step 6000: 1.849730
# Average loss at step 8000: 1.938016
# Average loss at step 10000: 1.337646
# Nearest to 7: 5, 6, 10, 8, 96,, figure,, 9, _______,
# Nearest to For: rules, room,, P15, Sara, scaled, Paul's, .2, machines,
# Nearest to What: Find, ex., Meg's, P39, The, calculator, -19, #32(You,
# Nearest to #6: #5, #28, #35, #8, Ten, 2/x=12/6., characteristic, annual,
# Nearest to Sorry,: New, √72, hypothesis?, values?, spending, degree?, average?, Good!,
# Nearest to write: enter, find, dismayed, include, meeting?, it,, Their, _________.,
# Nearest to 'Break: 638, P32, crops, sphere., hadn’t, #37(You, facing, -7.,
# Nearest to #2: #4, #24, (SSS,, #42, 90-92, #7, #48, Once,
# Nearest to Ms.: false(You, (No, 0.82,, ∏), popcorn, on?, sales?, 17(You,
# Nearest to value?: a*10^b.), outcomes, "draw, inches., protects, ideas., Some, 8n=2(You,
# Nearest to area.: values., plate, Negative, 376, rectangle?, 426, comparing, 1-10,
# Nearest to e: $2.00, 566, stars, judged, P25, -use, F?, prime,
# Nearest to -7: B)H0:, People,, 144,, 32, within, condition, correlation, (3,
# Nearest to exact: households, Express, now,, Post, bars?, E?, 0.83,, P.,
# Nearest to 204: _____., 2pi., 131, jeans, (leave, 57, 257, P5,
# Nearest to h,: $)(You, (Hint:, central, 115,, x), multiplicative, young, YOU,
# Average loss at step 12000: 1.294907
# Average loss at step 14000: 1.362277
# Average loss at step 16000: 1.389644
# Average loss at step 18000: 1.376308
# Average loss at step 20000: 0.795521
# Nearest to 7: 5, 6, rented., 9, 2.7, figure,, 96,, 10,
# Nearest to For: room,, An, Sara, 1:2, city, rules, scaled, eighth,
# Nearest to What: Find, (Do, #32(You, find, Meg's, The, Naomi, Rate:,
# Nearest to #6: #8, #5, #28, #35, #27, #22, #30, #7,
# Nearest to Sorry,: New, √72, hypothesis?, Good!, values?, Mode, Q, 50x,
# Nearest to write: enter, dismayed, include, it,, find, Their, meeting?, (8x,
# Nearest to 'Break: 638, P32, sphere., crops, hadn’t, reasonable, #37(You, Ratios,
# Nearest to #2: #4, #3, #24, #27, #7, (SSS,, #42, #20,
# Nearest to Ms.: false(You, (No, signs., 0.82,, sales?, on?, entire, 17(You,
# Nearest to value?: a*10^b.), outcomes, Some, 45s, nations, 214, "draw, weekly,
# Nearest to area.: plate, values., 376, rectangle?, Negative, 7., absolute, comparing,
# Nearest to e: $2.00, 566, stars, judged, Harrison, resources, -use, drain,
# Nearest to -7: (3, condition, People,, B)H0:, correlation, 144,, 32, 129,
# Nearest to exact: area?, statistical, households, now,, P., numerical, bars?, dancing.,
# Nearest to 204: _____., 131, 257, 2pi., P5, jeans, (leave, |-6|?,
# Nearest to h,: central, (Hint:, $)(You, 115,, focus, by:, (m2), Help:),
# Average loss at step 22000: 1.268612
# Average loss at step 24000: 1.109568
# Average loss at step 26000: 1.123108
# Average loss at step 28000: 0.883076
# Average loss at step 30000: 1.130874
# Nearest to 7: 5, 63, 6, rented., 2.7, 377, 361, 80,
# Nearest to For: 1:2, An, With, city, y..., .2, Sara, room,,
# Nearest to What: Find, The, Which, Enter, Rate:, P39, Don't, 66.,
# Nearest to #6: #8, #5, #4, #28, #30, #7, #22, #2,
# Nearest to Sorry,: New, Good!, √72, hypothesis?, Q, values?, 50x, Mode,
# Nearest to write: enter, dismayed, include, meeting?, Their, find, it,, 611,
# Nearest to 'Break: 638, sphere., reasonable, P32, crops, hadn’t, +4), Ratios,
# Nearest to #2: #4, #3, #1, #7, #14, #6, #24, #5,
# Nearest to Ms.: false(You, signs., (No, entire, 0.82,, sales?, on?, expect,
# Nearest to value?: a*10^b.), Some, weekly, nations, 45s, outcomes, 214, 80.,
# Nearest to area.: plate, rectangle?, absolute, 376, sum., 299, values., exact,
# Nearest to e: $2.00, 566, Harrison, rewrite, resources, stars, judged, ANSWER,
# Nearest to -7: (3, condition, People,, 129, correlation, 144,, B)H0:, 32,
# Nearest to exact: statistical, numerical, area?, missing, P., perimeter, n?, now,,
# Nearest to 204: 131, _____., 257, P5, |-6|?, 2pi., jeans, x=-5.,
# Nearest to h,: central, (Hint:, Help:), 115,, focus, by:, YOU, (m2),
# Average loss at step 32000: 0.975962
# Average loss at step 34000: 1.090789
# Average loss at step 36000: 0.920660
# Average loss at step 38000: 0.808726
# Average loss at step 40000: 1.016612
# Nearest to 7: 5, 6, 63, rented., 361, 9, 2.7, 12,
# Nearest to For: 1:2, An, city, y..., .2, Decide, With, sets,
# Nearest to What: Find, The, Meg's, excluded, Enter, Predict, 66., Based,
# Nearest to #6: #8, #5, #4, #28, #30, #2, #22, #3,
# Nearest to Sorry,: Q, New, Good!, √72, hypothesis?, values?, 50x, Mode,
# Nearest to write: enter, dismayed, include, find, Chapter, meeting?, round, it,,
# Nearest to 'Break: 638, sphere., reasonable, +4), crops, hadn’t, P32, Ratios,
# Nearest to #2: #4, #3, #1, #14, #6, ball?, #7, Help,
# Nearest to Ms.: false(You, signs., (No, entire, 0.82,, sales?, expect, on?,
# Nearest to value?: weekly, a*10^b.), Some, 45s, models, nations, (Continued), least,
# Nearest to area.: plate, sum., exact, absolute, rectangle?, 376, 299, x:,
# Nearest to e: $2.00, Harrison, resources, ANSWER, 566, 0,, -7(You, -use,
# Nearest to -7: (3, condition, People,, correlation, 129, kept, 144,, 32,
# Nearest to exact: statistical, numerical, area., perimeter, P., area?, bars?, missing,
# Nearest to 204: 131, 257, _____., 194, |-6|?, P5, 115, 158,
# Nearest to h,: central, Help:), (Hint:, focus, 115,, YOU, seeds, by:,
# Average loss at step 42000: 0.981136
# Average loss at step 44000: 1.091554
# Average loss at step 46000: 0.572309
# Average loss at step 48000: 1.007118
# Average loss at step 50000: 0.853014
# Nearest to 7: 5, 6, 63, 361, rented., 2.7, 8, 9,
# Nearest to For: 1:2, city, An, .2, With, sets, Thus, (For,
# Nearest to What: Find, The, Predict, 66., (Enter, Based, Which, Compute,
# Nearest to #6: #8, #5, #4, #28, #2, #7, #3, #30,
# Nearest to Sorry,: Q, Good!, √72, New, hypothesis?, 50x, Mode, values?,
# Nearest to write: enter, include, dismayed, find, greatest,, meeting?, snacks, appropriate,
# Nearest to 'Break: 638, sphere., reasonable, +4), #8, crops, hadn’t, P32,
# Nearest to #2: #4, #3, #1, #14, #6, #7, #24, ball?,
# Nearest to Ms.: signs., false(You, (No, entire, 0.82,, sales?, 17(You, expect,
# Nearest to value?: weekly, a*10^b.), Some, models, value., 45s, nations, (Capitalize,
# Nearest to area.: plate, absolute, exact, sum., x:, dimensions, 376, 299,
# Nearest to e: $2.00, resources, Harrison, 0,, -7(You, 566, -use, ANSWER,
# Nearest to -7: (3, condition, People,, 129, form:, correlation, 144,, kept,
# Nearest to exact: statistical, numerical, area., P., perimeter, classmate's, (Enter, approximate,
# Nearest to 204: 131, 257, 572, _____., 309, 363, 207, 3-6,
# Nearest to h,: central, Help:), focus, (Hint:, (m2), 115,, YOU, fixed,
# Average loss at step 52000: 0.945142
# Average loss at step 54000: 0.736270
# Average loss at step 56000: 0.904868
# Average loss at step 58000: 0.795600
# Average loss at step 60000: 0.932186
# Nearest to 7: 5, 63, 6, 8, 377, 9, 361, 141,
# Nearest to For: 1:2, city, With, .2, Thus, An, sets, (Assume,
# Nearest to What: Find, Enter, Rate:, The, Which, (Enter, Predict, Submit,
# Nearest to #6: #8, #4, #5, #28, #3, #1, #7, #2,
# Nearest to Sorry,: Q, Good!, √72, New, 50x, press, hypothesis?, 207,
# Nearest to write: enter, include, dismayed, find, round, greatest,, meeting?, leave,
# Nearest to 'Break: sphere., 638, +4), reasonable, hadn’t, crops, #8, Katie,
# Nearest to #2: #4, #3, #1, #14, #7, #6, #26, #24,
# Nearest to Ms.: (No, signs., entire, false(You, 17(You, Some, 3x?, sales?,
# Nearest to value?: weekly, models, value., a*10^b.), a?, 45s, (Continued), (Capitalize,
# Nearest to area.: x:, dimensions, sum., plate, exact, 376, absolute, 299,
# Nearest to e: $2.00, resources, Harrison, 0,, -7(You, -use, rewrite, √4?,
# Nearest to -7: (3, condition, form:, People,, park., 129, kept, correlation,
# Nearest to exact: P., statistical, area., numerical, perimeter, approximate, area?, comprehension,
# Nearest to 204: 131, 572, 257, 106, _____., 36, 2pi., 779,
# Nearest to h,: central, Help:), focus, (Hint:, 115,, YOU, (m2), fixed,
# Average loss at step 62000: 0.839483
# Average loss at step 64000: 0.624272
# Average loss at step 66000: 0.918466
# Average loss at step 68000: 0.804024
# Average loss at step 70000: 0.940906
# Nearest to 7: 5, 6, 63, 141, 9, 361, 12, 377,
# Nearest to For: 1:2, city, Thus, .2, With, (For, sets, (Assume,
# Nearest to What: Find, Enter, Which, The, Predict, (Do, According, How,
# Nearest to #6: #8, #4, #5, #28, #3, #27, #22, #24,
# Nearest to Sorry,: Q, Good!, √72, An, press, New, 50x, Mode,
# Nearest to write: enter, dismayed, include, find, leave, round, meeting?, greatest,,
# Nearest to 'Break: +4), sphere., 638, reasonable, hadn’t, crops, P32, Katie,
# Nearest to #2: #4, #3, #26, #1, #14, #76, #7, #6,
# Nearest to Ms.: (No, signs., entire, false(You, 17(You, Some, 65?, school,
# Nearest to value?: weekly, models, value., (Capitalize, a?, answer:, number?, 45s,
# Nearest to area.: dimensions, x:, plate, sum., exact, 376, below:, absolute,
# Nearest to e: $2.00, Harrison, resources, -7(You, 0,, -use, √4?, rewrite,
# Nearest to -7: condition, (3, park., form:, People,, moment., -6, 3x-2y+z+5,
# Nearest to exact: P., statistical, area., perimeter, numerical, approximate, on?, area?,
# Nearest to 204: 131, 149, 3-6, 779, 106, 309, 16, 36,
# Nearest to h,: central, focus, (Hint:, Help:), fixed, 115,, (m2), YOU,
# Average loss at step 72000: 0.537281
# Average loss at step 74000: 0.894012
# Average loss at step 76000: 0.744283
# Average loss at step 78000: 0.859438
# Average loss at step 80000: 0.668033
# Nearest to 7: 5, 6, 8, settlement,, 63, 12, 126, 7/8,
# Nearest to For: 1:2, city, With, Thus, (For, .2, sets, (Assume,
# Nearest to What: Find, Determine, Which, The, Predict, Compute, Write, Enter,
# Nearest to #6: #8, #4, #5, #28, #22, #66, #24, #3,
# Nearest to Sorry,: Q, Good!, An, √72, press, -3x, 50x, 207,
# Nearest to write: enter, dismayed, include, find, greatest,, leave, meeting?, snacks,
# Nearest to 'Break: +4), 638, sphere., reasonable, hadn’t, crops, Katie, P32,
# Nearest to #2: #4, #3, #14, #26, #1, #76, #59, #7,
# Nearest to Ms.: (No, signs., entire, false(You, 17(You, school, Some, 65?,
# Nearest to value?: weekly, value., (Capitalize, models, answer:, number?, a?, function:,
# Nearest to area.: dimensions, x:, plate, 376, exact, 3.14., sum., absolute,
# Nearest to e: $2.00, Harrison, 0,, resources, -7(You, rewrite, -use, √4?,
# Nearest to -7: condition, (3, form:, park., 3x-2y+z+5, moment., -6, People,,
# Nearest to exact: P., statistical, approximate, numerical, perimeter, area., comprehension, on?,
# Nearest to 204: 131, 3-6, 790, 149, 797, 115, 199, 106,
# Nearest to h,: central, Help:), focus, (Hint:, fixed, 115,, (m2), YOU,
# Average loss at step 82000: 0.730744
# Average loss at step 84000: 0.760380
# Average loss at step 86000: 0.814565
# Average loss at step 88000: 0.820489
# Average loss at step 90000: 0.545281
# Nearest to 7: 5, 63, 6, 8, (-14), 9, 126, 361,
# Nearest to For: 1:2, Thus, (For, With, (Assume, city, sets, .2,
# Nearest to What: Find, Write, ex., Predict, Determine, Remember,, Compute, Rate:,
# Nearest to #6: #8, #4, #5, #28, #24, #66, #22, #30,
# Nearest to Sorry,: Q, An, Good!, press, √72, -3x, 50x, Mode,
# Nearest to write: enter, dismayed, include, find, leave, meeting?, greatest,, round,
# Nearest to 'Break: +4), 638, reasonable, sphere., hadn’t, crops, 11,, facing,
# Nearest to #2: #4, #3, #1, #14, #26, #76, #59, Eg.,
# Nearest to Ms.: (No, signs., false(You, entire, school, 17(You, 3x?, sales?,
# Nearest to value?: weekly, value., (Capitalize, number?, answer:, models, a?, function:,
# Nearest to area.: dimensions, x:, plate, 3.14., and/or, exact, 376, sum.,
# Nearest to e: $2.00, resources, Harrison, -7(You, -use, 0,, √4?, rewrite,
# Nearest to -7: condition, (3, form:, park., 3x-2y+z+5, (-4), -6, moment.,
# Nearest to exact: P., statistical, approximate, numerical, perimeter, area., 48., comprehension,
# Nearest to 204: 131, 253, 106, 149, 3-6, 797, 115, 199,
# Nearest to h,: central, Help:), focus, (Hint:, quotient, YOU, 115,, fixed,
# Average loss at step 92000: 0.815612
# Average loss at step 94000: 0.706944
# Average loss at step 96000: 0.811106
# Average loss at step 98000: 0.580382
# Average loss at step 100000: 0.791937
# Nearest to 7: 63, 5, 6, 361, (-14), 126, settlement,, rented.,
# Nearest to For: 1:2, (Assume, With, Thus, (For, city, sets, .2,
# Nearest to What: Find, Determine, Which, Predict, Describe, Enter, The, Compute,
# Nearest to #6: #8, #4, #28, #5, #24, #66, #30, #22,
# Nearest to Sorry,: Q, Good!, -3x, An, press, √72, 50x, 207,
# Nearest to write: enter, dismayed, include, leave, find, meeting?, snacks, it,,
# Nearest to 'Break: +4), 638, reasonable, sphere., hadn’t, crops, 11,, showing,
# Nearest to #2: #4, #3, #14, #76, #1, #26, #59, ball?,
# Nearest to Ms.: (No, signs., entire, false(You, school, 17(You, How, Some,
# Nearest to value?: weekly, value., (Capitalize, answer:, number?, a?, models, function:,
# Nearest to area.: dimensions, x:, plate, 3.14., and/or, exact, below:, sum.,
# Nearest to e: $2.00, Harrison, -use, resources, -7(You, rewrite, 0,, √4?,
# Nearest to -7: form:, (3, condition, -6, 3x-2y+z+5, -15, (-4), moment.,
# Nearest to exact: statistical, P., numerical, area., 48., approximate, a?, comprehension,
# Nearest to 204: 131, 253, 106, 3-6, 199, 115, 797, 149,
# Nearest to h,: Help:), central, focus, YOU, quotient, 115,, (Hint:, fixed,
